# %% [markdown]
# # GIF输出
# `mimwrite`(alias: mimsave)函数

# %%
# %matplotlib notebook
import imageio
import matplotlib.pyplot as plt

reader = imageio.get_reader('<video0>')
plt.show()
plt.imshow(reader.get_next_data(), clim=(0, 255))
for im in reader:
    plt.imshow(reader.get_next_data(), clim=(0, 255))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-b0bd3ea0d94d> in <module>()
#       3 import matplotlib.pyplot as plt
#       4
# ----> 5 reader = imageio.get_reader('<video0>')
#       6 plt.show()
#       7 plt.imshow(reader.get_next_data(), clim=(0, 255))
#
# ~/.local/lib/python3.6/site-packages/imageio/core/functions.py in get_reader(uri, format, mode, **kwargs)
#     127
#     128     # Return its reader object
# --> 129     return format.get_reader(request)
#     130
#     131
#
# ~/.local/lib/python3.6/site-packages/imageio/core/format.py in get_reader(self, request)
#     166             raise RuntimeError('Format %s cannot read in mode %r' %
#     167                                (self.name, select_mode))
# --> 168         return self.Reader(self, request)
#     169
#     170     def get_writer(self, request):
#
# ...

# %%
import imageio
import visvis as vv

vol = imageio.volread('imageio:stent.npz')
vv.volshow(vol)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/OpenGL/platform/glx.py in GL(self)
#      16                 'GL',
# ---> 17                 mode=ctypes.RTLD_GLOBAL
#      18             )
#
# ~/.local/lib/python3.6/site-packages/OpenGL/platform/ctypesloader.py in loadLibrary(dllType, name, mode)
#      44     try:
# ---> 45         return dllType( name, mode )
#      46     except Exception as err:
#
# /usr/lib/python3.6/ctypes/__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error)
#     347         if handle is None:
# --> 348             self._handle = _dlopen(self._name, mode)
#     349         else:
#
# OSError: ('GL: cannot open shared object file: No such file or directory', 'GL', None)
#
# During handling of the above exception, another exception occurred:
#
# ...
